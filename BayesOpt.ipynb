# %% [markdown]
# - 概率代理模型：
# 根据有限的观测值，对函数分布进行估计的工具。
# 自带某些假设，可以根据少量观测点估计出目标函数的分布（函数值及其置信度）
# 常见概率代理模型：
# 高斯过程、高斯混合模型等。
# 现在最普及的优化库默认基于高斯混合模型的TPE过程
#
# - 采集函数：
# 确定下一个观测点的规则。
# 衡量观测点对拟合函数所产生的影响，选取影响最大的点。
# 常见采集函数：
# 概率增量PI、期望增量、置信度上界、信息熵等。
# 现在大部分优化库使用期望增量。

# %% [markdown]
# ## 导入库，确认使用数据

# %%
# 基本工具
import numpy as np
import pandas as pd
import time
import os

# 算法/损失/评估指标等
import sklearn
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.model_selection import KFold,cross_validate

# 优化器
import bayes_opt
from bayes_opt import BayesianOptimization
import hyperopt
from hyperopt import hp,fmin,tpe,Trials,partial
from hyperopt.early_stop import no_progress_loss
import optuna

# %%
print(hyperopt.__version__)
# Out:
# 0.2.7

# %%
print(optuna.__version__)
# Out:
# 2.10.0

# %%
data = pd.read_csv(r"/Users/feishuoren/Projects/machine_learning/datasets/HousePrice/train_encode.csv",index_col=0)
data.head()

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

X.head()

# %%
X.shape

# %% [markdown]
# 使用贝叶斯优化是为了提高速度，而高斯过程不够快，因此使用高斯过程的贝叶斯优化逐渐被舍弃

# %% [markdown]
# ## 基于 Bayes_opt 实现 GP 优化

# %% [markdown]
# 1.定义目标函数
# ```
# def objective():
#     # 评估器
#     reg = RFR()
#     # 交叉验证
#     cv = KFold()
#     result = cross_validate(reg,cv)
#     # 交叉验证的结果
#     loss  = result("test_rmse")
#
#     return loss
# ```

# %%
def bayesopt_objective(n_estimators,max_depth,max_features,min_impurity_decrease):
    # 定义评估器
    # 需要调整的参数等于目标函数的输入，不需要调整的超参数则直接等于固定值
    # 默认参数输入一定是浮点数，因此需要套上int函数整理成整数
    reg = RFR(n_estimators = int(n_estimators)
             ,max_depth = int(max_depth)
             ,max_features = int(max_features)
             ,min_impurity_decrease = min_impurity_decrease
             ,random_state = 1412
             ,verbose = False# 可自行决定是否开启森林建树的verbose
             ,n_jobs = -1)
    
    # 定义损失函数的输出，5折交叉验证下的结果，输出负根均方误差（-RMSE）
    # 注意，交叉验证需要使用数据，但我们不能让数据X,y成为目标函数的输入
    cv = KFold(n_splits=5,shuffle=True,random_state=1412)
    validation_loss = cross_validate(reg,X,y
                                  ,scoring = "neg_root_mean_squared_error"
                                  ,cv = cv
                                  ,verbose = False
                                  ,n_jobs = -1
                                  ,error_score = 'raise'
                                  #如果交叉验证中的算法执行报错，则告诉我们错误的理由
                                  )
    
    # 交叉验证输出的评估指标是负根均方误差，因此本来就是负的损失
    # 目标函数可直接输出该损失的均值
    return np.mean(validation_loss["test_score"])

# %% [markdown]
# 2.定义参数空间

# %%
param_grid_simple = {'n_estimators':(80,100)
                    ,'max_depth':(10,25)
                    ,'max_features':(10,20)
                    ,'min_impurity_decrease':(0,1)
                    }

# %% [markdown]
# 3.定义优化目标函数的具体流程

# %%
def param_bayes_opt(init_points,n_iter):
    # 定义优化器，先实例化优化器
    opt = BayesianOptimization(bayesopt_objective #需要优化的目标函数
                              ,param_grid_simple #备选参数空间
                              ,random_state = 1412 #随机数种子，虽然无法控制住
                              )
    # 使用优化器，记住bayes_opt只支持最大化
    opt.maximize(init_points = init_points # 抽取多少个初始观测值
                ,n_iter = n_iter # 一共观测/迭代多少次
                )
    # 优化完成，取出最佳参数与最佳分数
    params_best = opt.max["params"]
    score_best = opt.max["target"]
    
    # 打印最佳参数与最佳分数
    print("\n","\n","best params:",params_best,
         "\n","\n","best cvscore:",score_best)
    # 返回最佳参数与最佳分数
    return params_best,score_best

# %% [markdown]
# 4.定义验证函数（非必需）

# %%
def bayes_opt_validation(params_best):
    reg = RFR(n_estimators = int(params_best["n_estimators"])
             ,max_depth = int(params_best["max_depth"])
             ,max_features = int(params_best["max_features"])
             ,min_impurity_decrease = params_best["min_impurity_decrease"]
             ,random_state = 1412
             ,verbose = False
             ,n_jobs = -1)
    cv = KFold(n_splits=5,shuffle=True,random_state=1412)
    validation_loss = cross_validate(reg,X,y
                                    ,scoring="neg_root_mean_squared_error"
                                    ,cv=cv
                                    ,verbose=False
                                    ,n_jobs=-1
                                    )
    return np.mean(validation_loss["test_score"])

# %% [markdown]
# 5.执行实际优化流程

# %%
start = time.time()
params_best,score_best = param_bayes_opt(20,280) # 初始20个观测值，之后迭代280次
print('It takes %s minutes' % ((time.time() - start)/60))
validation_score = bayes_opt_validation(params_best)
print("\n","\n","validation_score:",validation_score)

# %% [markdown]
# ## 基于Optuna的贝叶斯优化

# %%
optuna.__version__

# %% [markdown]
# 1. 定义目标函数和参数空间

# %%
def optuna_objective(trial):
    # 定义参数空间
    n_estimators = trial.suggest_int("n_estimators",80,100,1) # 整数型，（参数名称，下界，上界，步长）
    max_depth = trial.suggest_int("max_depth",10,25,1)
    max_features = trial.suggest_int("max_features",10,20,1)
    min_impurity_decrease = trial.suggest_int("min_impurity_decrease",0,5,1)
    
    # 定义评估器
    # 需要优化的参数由上述参数空间决定
    # 不需要优化的参数则直接填写具体值
    reg = RFR(n_estimators = n_estimators
             ,max_depth = max_depth
             ,max_features = max_features
             ,min_impurity_decrease = min_impurity_decrease
             ,random_state = 1412
             ,verbose = False
             ,n_jobs = -1
             )
    # 交叉验证过程，输出负均方根误差（- RMSE）
    # optuna同时支持最大化和最小化，因此如果输出- RMSE，则选择最大化
    # 如果选择输出RMSE，则选择最小化
    cv = KFold(n_splits = 5,shuffle = True,random_state=1412)
    validation_loss = cross_validate(reg,X,y
                                    ,scoring="neg_root_mean_squared_error"
                                    ,cv=cv # 交叉验证模式
                                    ,verbose=False # 是否打印进程
                                    ,n_jobs=-1 # 线程数
                                    ,error_score='raise'
                                    )
    # 最终输出RMSE
    return np.mean(abs(validation_loss["test_score"]))

# %% [markdown]
# 2.定义优化目标函数的具体流程

# %%
def optimizer_optuna(n_trials,algo):
    # 定义使用TPE或者GP
    if algo == "TPE":
        algo = optuna.samplers.TPESampler(n_startup_trials=10,n_ei_candidates=24)

    elif algo == "GP":
        from optuna.integration import SkoptSampler
        import skopt
        algo = SkoptSampler(skopt_kwargs = {'base_estimator':'GP', # 选择高斯过程
                                           'n_initial_points':10, # 初始观测点10个
                                           'acq_func':'EI'} # 选择的采集函数为EI，期望增量
                           )
        
    # 实际优化过程，首先实例化优化器
    study = optuna.create_study(sampler = algo # 要使用的具体算法
                               ,direction = 'minimize' # 优化的方向，可以填写minimize或maxmize
                               )
    # 开始优化，n_trials为允许的最大迭代次数
    # 由于参数空间已经在目标函数汇总定义好，因此不需要输入参数空间
    study.optimize(optuna_objective # 目标函数
                   ,n_trials=n_trials # 最大迭代次数（包括最初的观测值）
                   ,show_progress_bar=True # 要不要展示进度条 
                  )

    # 可直接从优化好的对象study中调用优化的结果
    # 打印最佳参数与最佳损失值
    print("\n","\n","best params:",study.best_trial.params,
         "\n","\n","best score:",study.best_trial.values,
         "\n")

    return study.best_trial.params,study.best_trial.values

# %% [markdown]
# 3. 执行实际优化流程

# %%
import warnings
warnings.filterwarnings('ignore',message='The objective has been evaluated at this point before.')

# %%
best_params,best_score = optimizer_optuna(10,"GP") # 默认打印迭代过程
# Out:
# [I 2022-05-12 16:39:39,214] A new study created in memory with name: no-name-5a264b58-c9f1-4845-9dbd-08d8b7dd2171
# /Users/feishuoren/anaconda3/lib/python3.8/site-packages/optuna/progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# [I 2022-05-12 16:39:40,587] Trial 0 finished with value: 29488.60038952484 and parameters: {'n_estimators': 92, 'max_depth': 15, 'max_features': 12, 'min_impurity_decrease': 5}. Best is trial 0 with value: 29488.60038952484.
# [I 2022-05-12 16:39:42,124] Trial 1 finished with value: 29210.47071276735 and parameters: {'n_estimators': 92, 'max_depth': 16, 'max_features': 18, 'min_impurity_decrease': 2}. Best is trial 1 with value: 29210.47071276735.
# [I 2022-05-12 16:39:43,825] Trial 2 finished with value: 28978.47401450302 and parameters: {'n_estimators': 86, 'max_depth': 18, 'max_features': 16, 'min_impurity_decrease': 1}. Best is trial 2 with value: 28978.47401450302.
# [I 2022-05-12 16:39:45,183] Trial 3 finished with value: 29548.169540535288 and parameters: {'n_estimators': 84, 'max_depth': 12, 'max_features': 15, 'min_impurity_decrease': 0}. Best is trial 2 with value: 28978.47401450302.
# [I 2022-05-12 16:39:46,918] Trial 4 finished with value: 29234.168560230122 and parameters: {'n_estimators': 94, 'max_depth': 13, 'max_features': 16, 'min_impurity_decrease': 0}. Best is trial 2 with value: 28978.47401450302.
# [I 2022-05-12 16:39:48,741] Trial 5 finished with value: 28880.331827383034 and parameters: {'n_estimators': 95, 'max_depth': 25, 'max_features': 20, 'min_impurity_decrease': 2}. Best is trial 5 with value: 28880.331827383034.
# [I 2022-05-12 16:39:50,468] Trial 6 finished with value: 29027.250312878186 and parameters: {'n_estimators': 97, 'max_depth': 17, 'max_features': 15, 'min_impurity_decrease': 3}. Best is trial 5 with value: 28880.331827383034.
# [I 2022-05-12 16:39:52,313] Trial 7 finished with value: 28868.452282904538 and parameters: {'n_estimators': 99, 'max_depth': 16, 'max_features': 19, 'min_impurity_decrease': 2}. Best is trial 7 with value: 28868.452282904538.
# [I 2022-05-12 16:39:53,669] Trial 8 finished with value: 28975.68788700184 and parameters: {'n_estimators': 82, 'max_depth': 14, 'max_features': 14, 'min_impurity_decrease': 1}. Best is trial 7 with value: 28868.452282904538.
# [I 2022-05-12 16:39:55,339] Trial 9 finished with value: 29049.050979350934 and parameters: {'n_estimators': 90, 'max_depth': 14, 'max_features': 19, 'min_impurity_decrease': 2}. Best is trial 7 with value: 28868.452282904538.
#
#
#
#  best params: {'n_estimators': 99, 'max_depth': 16, 'max_features': 19, 'min_impurity_decrease': 2}
#
#  best score: [28868.452282904538]

# %%
# optuna.logging.set_verbosity(optuna.logging.ERROR) # 关闭自动打印的info，只显示进度条
optuna.logging.set_verbosity(optuna.logging.INFO)
best_params,best_score = optimizer_optuna(300,"TPE")
# Out:
# [I 2022-05-12 16:39:55,372] A new study created in memory with name: no-name-fe331986-2b3b-41e1-a620-2e86f615cc66
# /Users/feishuoren/anaconda3/lib/python3.8/site-packages/optuna/progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# [I 2022-05-12 16:39:56,878] Trial 0 finished with value: 29241.447258310487 and parameters: {'n_estimators': 96, 'max_depth': 19, 'max_features': 13, 'min_impurity_decrease': 2}. Best is trial 0 with value: 29241.447258310487.
# [I 2022-05-12 16:39:58,199] Trial 1 finished with value: 29626.373884342098 and parameters: {'n_estimators': 86, 'max_depth': 12, 'max_features': 15, 'min_impurity_decrease': 1}. Best is trial 0 with value: 29241.447258310487.
# [I 2022-05-12 16:39:59,439] Trial 2 finished with value: 29651.927712838555 and parameters: {'n_estimators': 83, 'max_depth': 25, 'max_features': 12, 'min_impurity_decrease': 0}. Best is trial 0 with value: 29241.447258310487.
# [I 2022-05-12 16:40:00,809] Trial 3 finished with value: 28622.400683646098 and parameters: {'n_estimators': 100, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 5}. Best is trial 3 with value: 28622.400683646098.
# [I 2022-05-12 16:40:01,838] Trial 4 finished with value: 29310.484424566886 and parameters: {'n_estimators': 89, 'max_depth': 13, 'max_features': 11, 'min_impurity_decrease': 5}. Best is trial 3 with value: 28622.400683646098.
# [I 2022-05-12 16:40:02,987] Trial 5 finished with value: 29111.933511873467 and parameters: {'n_estimators': 91, 'max_depth': 13, 'max_features': 13, 'min_impurity_decrease': 4}. Best is trial 3 with value: 28622.400683646098.
# [I 2022-05-12 16:40:04,261] Trial 6 finished with value: 29273.47380267827 and parameters: {'n_estimators': 93, 'max_depth': 13, 'max_features': 16, 'min_impurity_decrease': 2}. Best is trial 3 with value: 28622.400683646098.
# [I 2022-05-12 16:40:05,817] Trial 7 finished with value: 28888.156389528805 and parameters: {'n_estimators': 96, 'max_depth': 22, 'max_features': 19, 'min_impurity_decrease': 0}. Best is trial 3 with value: 28622.400683646098.
# [I 2022-05-12 16:40:07,060] Trial 8 finished with value: 29188.620297742884 and parameters: {'n_estimators': 92, 'max_depth': 11, 'max_features': 16, 'min_impurity_decrease': 0}. Best is trial 3 with value: 28622.400683646098.
# [I 2022-05-12 16:40:08,629] Trial 9 finished with value: 28805.02732907121 and parameters: {'n_estimators': 98, 'max_depth': 23, 'max_features': 20, 'min_impurity_decrease': 3}. Best is trial 3 with value: 28622.400683646098.
# [I 2022-05-12 16:40:09,818] Trial 10 finished with value: 29433.448833369883 and parameters: {'n_estimators': 100, 'max_depth': 18, 'max_features': 10, 'min_impurity_decrease': 5}. Best is trial 3 with value: 28622.400683646098.
# [I 2022-05-12 16:40:11,471] Trial 11 finished with value: 28981.338256846473 and parameters: {'n_estimators': 100, 'max_depth': 25, 'max_features': 19, 'min_impurity_decrease': 3}. Best is trial 3 with value: 28622.400683646098.
# [I 2022-05-12 16:40:12,982] Trial 12 finished with value: 29046.766636071297 and parameters: {'n_estimators': 97, 'max_depth': 22, 'max_features': 20, 'min_impurity_decrease': 4}. Best is trial 3 with value: 28622.400683646098.
# [I 2022-05-12 16:40:14,267] Trial 13 finished with value: 29365.506583431743 and parameters: {'n_estimators': 80, 'max_depth': 22, 'max_features': 17, 'min_impurity_decrease': 3}. Best is trial 3 with value: 28622.400683646098.
# [I 2022-05-12 16:40
and parameters: {'n_estimators': 89, 'max_depth': 24, 'max_features': 15, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:34,112] Trial 278 finished with value: 28933.739533678872 and parameters: {'n_estimators': 88, 'max_depth': 25, 'max_features': 13, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:35,265] Trial 279 finished with value: 28592.025021150395 and parameters: {'n_estimators': 89, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:36,470] Trial 280 finished with value: 28980.64477938537 and parameters: {'n_estimators': 89, 'max_depth': 25, 'max_features': 13, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:37,694] Trial 281 finished with value: 28623.59006632356 and parameters: {'n_estimators': 88, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:38,948] Trial 282 finished with value: 28592.025021150395 and parameters: {'n_estimators': 89, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:40,139] Trial 283 finished with value: 28592.025021150395 and parameters: {'n_estimators': 89, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:41,327] Trial 284 finished with value: 28592.025021150395 and parameters: {'n_estimators': 89, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:42,575] Trial 285 finished with value: 28592.025021150395 and parameters: {'n_estimators': 89, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:43,798] Trial 286 finished with value: 28683.668872074493 and parameters: {'n_estimators': 89, 'max_depth': 25, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:45,174] Trial 287 finished with value: 28592.025021150395 and parameters: {'n_estimators': 89, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:46,566] Trial 288 finished with value: 28592.025021150395 and parameters: {'n_estimators': 89, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:47,888] Trial 289 finished with value: 29390.22704899929 and parameters: {'n_estimators': 89, 'max_depth': 24, 'max_features': 15, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:49,440] Trial 290 finished with value: 28718.414658242487 and parameters: {'n_estimators': 88, 'max_depth': 25, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:50,625] Trial 291 finished with value: 29026.871224363604 and parameters: {'n_estimators': 87, 'max_depth': 24, 'max_features': 13, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:51,846] Trial 292 finished with value: 29089.969176833052 and parameters: {'n_estimators': 89, 'max_depth': 14, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:53,312] Trial 293 finished with value: 28592.025021150395 and parameters: {'n_estimators': 89, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:54,770] Trial 294 finished with value: 28623.59006632356 and parameters: {'n_estimators': 88, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:56,221] Trial 295 finished with value: 28683.668872074493 and parameters: {'n_estimators': 89, 'max_depth': 25, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:57,621] Trial 296 finished with value: 29778.146962525334 and parameters: {'n_estimators': 89, 'max_depth': 11, 'max_features': 15, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:46:58,988] Trial 297 finished with value: 28623.59006632356 and parameters: {'n_estimators': 88, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:47:00,373] Trial 298 finished with value: 28592.025021150395 and parameters: {'n_estimators': 89, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
# [I 2022-05-12 16:47:01,679] Trial 299 finished with value: 28592.025021150395 and parameters: {'n_estimators': 89, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}. Best is trial 219 with value: 28592.025021150395.
#
#
#
#  best params: {'n_estimators': 89, 'max_depth': 24, 'max_features': 14, 'min_impurity_decrease': 4}
#
#  best score: [28592.025021150395]

# %%
optuna.logging.set_verbosity(optuna.logging.ERROR)
best_params,best_score = optimizer_optuna(300,"GP")
# Out:
# /Users/feishuoren/anaconda3/lib/python3.8/site-packages/optuna/progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
#
#  best params: {'n_estimators': 89, 'max_depth': 23, 'max_features': 14, 'min_impurity_decrease': 0}
#
#  best score: [28496.546454099334]

# %% [markdown]
# ## 基于 HyperOpt 实现TPE优化
# - 目标函数的输入必须是符合hyperopt规定的字典
# - Hyoeropt只支持寻找函数f(x)的最小值，不支持寻找最大值

# %%
hyperopt.__version__
# Out:
# '0.2.7'

# %%
from hyperopt import hp,fmin,tpe,Trials,partial
from hyperopt.early_stop import no_progress_loss

# %% [markdown]
# 1.定义目标函数

# %%
def hyperopt_objective(params):
    # 定义评估器
    # 需要搜索的参数需要从输入的字典中索引出来
    # 不需要搜索的参数，可以是设置好的某个值
    # 在需要整数的参数前调整参数类型
    reg = RFR(n_estimators = int(params["n_estimators"])
             ,max_depth = int(params["max_depth"])
             ,max_features = int(params["max_features"])
             ,min_impurity_decrease = params["min_impurity_decrease"]
             ,random_state=1412
             ,verbose=False
             ,n_jobs=-1)
    
    # 交叉验证结果，输出负根均方误差（- RMSE）
    cv = KFold(n_splits=5,shuffle=True,random_state=1412)
    validation_loss = cross_validate(reg,X,y
                                    ,scoring="neg_root_mean_squared_error"
                                    ,cv=cv
                                    ,verbose=False
                                    ,n_jobs=-1
                                    ,error_score='raise'
                                    )
    
    # 最终输出结果，由于只能取最小值，所以必须对（- RMSE）求绝对值
    # 以求解最小RMSE所对应的参数组合
    return np.mean(abs(validation_loss["test_score"]))

# %% [markdown]
# 2.定义参数空间

# %%
param_grid_simple = {'n_estimators':hp.quniform("n_estimators",80,100,1)
                    ,'max_depth':hp.quniform("max_depth",10,25,1)
                    ,"max_features":hp.quniform("max_features",10,20,1)
                    ,"min_impurity_decrease":hp.quniform("min_impurity_decrease",0,5,1)
                    }

# %%
# 计算当前参数空间的大小
len([*range(80,100,1)])*len([*range(10,25,1)])*len([*range(10,20,1)])*len([range(0,5,1)])
# Out:
# 3000

# %% [markdown]
# 3.定义优化目标函数的具体流程

# %%
def param_hyperopt(max_evals=100):
    # 保存迭代过程
    trials = Trials()
    
    # 设置提前停止
    early_stop_fn = no_progress_loss(100)
    
    # 定义代理模型
    # algo = partial(tpe,suggest,n_startup_jobs=20,n_EI_cadidates=50)
    params_best = fmin(hyperopt_objective # 目标函数
                      ,space = param_grid_simple # 参数空间
                      ,algo = tpe.suggest # 代理模型的选择
                      # ,algo = algo
                      ,max_evals = max_evals # 允许的迭代次数
                      ,verbose = True
                      ,trials = trials
                      ,early_stop_fn = early_stop_fn
                      )
    
    # 打印最优参数，fmin会自动打印最佳分数
    print("\n","\n","best params:",params_best,
         "\n")
    return params_best,trials

# %% [markdown]
# 4.定义验证函数（非必要）

# %%
def hyperopt_validation(params):
    reg = RFR(n_estimators = int(params["n_estimators"])
             ,max_depth = int(params["max_depth"])
             ,max_features = int(params["max_features"])
             ,min_impurity_decrease = params["min_impurity_decrease"]
             ,random_state = 1412
             ,verbose = False
             ,n_jobs=-1
             )
    cv = KFold(n_splits=5,shuffle=True,random_state=1412)
    validation_loss = cross_validate(reg,X,y
                                    ,scoring="neg_root_mean_squared_error"
                                    ,cv=cv
                                    ,verbose=False
                                    ,n_jobs=-1
                                    )
    return np.mean(abs(validation_loss["test_score"]))

# %% [markdown]
# 5.执行实际优化流程

# %%
params_best,trials = param_hyperopt(30) # 1%的空间大小
# Out:
# 100%|██████████| 30/30 [00:36<00:00,  1.21s/trial, best loss: 28601.70869989323]
#
#
#  best params: {'max_depth': 23.0, 'max_features': 14.0, 'min_impurity_decrease': 2.0, 'n_estimators': 97.0}

# %%
params_best,trials = param_hyperopt(100) # 3%的空间大小
# Out:
# 100%|██████████| 100/100 [02:55<00:00,  1.75s/trial, best loss: 28554.697924803077]
#
#
#  best params: {'max_depth': 15.0, 'max_features': 18.0, 'min_impurity_decrease': 2.0, 'n_estimators': 100.0}

# %%
params_best,trials = param_hyperopt(300) # 10%的空间大小
# Out:
#  60%|█████▉    | 179/300 [04:27<03:00,  1.49s/trial, best loss: 28519.483540374506]
#
#
#  best params: {'max_depth': 15.0, 'max_features': 18.0, 'min_impurity_decrease': 0.0, 'n_estimators': 96.0}

# %%
hyperopt_validation(params_best)
# Out:
# 28519.483540374506

# %%
# 打印所有搜索相关的记录
trials.trials
# Out:
# [{'state': 2,
#   'tid': 0,
#   'spec': None,
#   'result': {'loss': 28787.195919814818, 'status': 'ok'},
#   'misc': {'tid': 0,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [0],
#     'max_features': [0],
#     'min_impurity_decrease': [0],
#     'n_estimators': [0]},
#    'vals': {'max_depth': [13.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [87.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 11, 59, 56, 728000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 11, 59, 58, 550000)},
#  {'state': 2,
#   'tid': 1,
#   'spec': None,
#   'result': {'loss': 28772.192469297763, 'status': 'ok'},
#   'misc': {'tid': 1,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [1],
#     'max_features': [1],
#     'min_impurity_decrease': [1],
#     'n_estimators': [1]},
#    'vals': {'max_depth': [12.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [92.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 11, 59, 58, 558000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 0, 293000)},
#  {'state': 2,
#   'tid': 2,
#   'spec': None,
#   'result': {'loss': 29610.116204633774, 'status': 'ok'},
#   'misc': {'tid': 2,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [2],
#     'max_features': [2],
#     'min_impurity_decrease': [2],
#     'n_estimators': [2]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 0, 300000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 2, 196000)},
#  {'state': 2,
#   'tid': 3,
#   'spec': None,
#   'result': {'loss': 28897.026322247082, 'status': 'ok'},
#   'misc': {'tid': 3,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [3],
#     'max_features': [3],
#     'min_impurity_decrease': [3],
#     'n_estimators': [3]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [89.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 2, 207000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 3, 939000)},
#  {'state': 2,
#   'tid': 4,
#   'spec': None,
#   'result': {'loss': 29132.443539912598, 'status': 'ok'},
#   'misc': {'tid': 4,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [4],
#     'max_features': [4],
#     'min_impurity_decrease': [4],
#     'n_estimators': [4]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [90.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 3, 948000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 5, 564000)},
#  {'state': 2,
#   'tid': 5,
#   'spec': None,
#   'result': {'loss': 29757.522728076416, 'status': 'ok'},
#   'misc': {'tid': 5,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [5],
#     'max_features': [5],
#     'min_impurity_decrease': [5],
#     'n_estimators': [5]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [93.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 5, 571000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 7, 328000)},
#  {'state': 2,
#   'tid': 6,
#   'spec': None,
#   'result': {'loss': 28540.341871995188, 'status': 'ok'},
#   'misc': {'tid': 6,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [6],
#     'max_features': [6],
#     'min_impurity_decrease': [6],
#     'n_estimators': [6]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 7, 338000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 9, 431000)},
#  {'state': 2,
#   'tid': 7,
#   'spec': None,
#   'result': {'loss': 29257.369603277337, 'status': 'ok'},
#   'misc': {'tid': 7,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [7],
#     'max_features': [7],
#     'min_impurity_decrease': [7],
#     'n_estimators': [7]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [98.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 9, 440000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 11, 608000)},
#  {'state': 2,
#   'tid': 8,
#   'spec': None,
#   'result': {'loss': 29572.80374604288, 'status': 'ok'},
#   'misc': {'tid': 8,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [8],
#     'max_features': [8],
#     'min_impurity_decrease': [8],
#     'n_estimators': [8]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [99.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 11, 614000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 13, 408000)},
#  {'state': 2,
#   'tid': 9,
#   'spec': None,
#   'result': {'loss': 29030.04648083298, 'status': 'ok'},
#   'misc': {'tid': 9,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [9],
#     'max_features': [9],
#     'min_impurity_decrease': [9],
#     'n_estimators': [9]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [85.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 13, 414000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 15, 142000)},
#  {'state': 2,
#   'tid': 10,
#   'spec': None,
#   'result': {'loss': 29629.841942221225, 'status': 'ok'},
#   'misc': {'tid': 10,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [10],
#     'max_features': [10],
#     'min_impurity_decrease': [10],
#     'n_estimators': [10]},
#    'vals': {'max_depth': [11.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [90.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 15, 148000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 16, 632000)},
#  {'state': 2,
#   'tid': 11,
#   'spec': None,
#   'result': {'loss': 28527.59824667769, 'status': 'ok'},
#   'misc': {'tid': 11,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [11],
#     'max_features': [11],
#     'min_impurity_decrease': [11],
#     'n_estimators': [11]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [80.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 16, 641000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 18, 326000)},
#  {'state': 2,
#   'tid': 12,
#   'spec': None,
#   'result': {'loss': 29413.881495818136, 'status': 'ok'},
#   'misc': {'tid': 12,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [12],
#     'max_features': [12],
#     'min_impurity_decrease': [12],
#     'n_estimators': [12]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [11.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [100.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 18, 333000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 20, 110000)},
#  {'state': 2,
#   'tid': 13,
#   'spec': None,
#   'result': {'loss': 29741.01018346257, 'status': 'ok'},
#   'misc': {'tid': 13,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [13],
#     'max_features': [13],
#     'min_impurity_decrease': [13],
#     'n_estimators': [13]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [87.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 20, 117000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 21, 793000)},
#  {'state': 2,
#   'tid': 14,
#   'spec': None,
#   'result': {'loss': 29362.050106738043, 'status': 'ok'},
#   'misc': {'tid': 14,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [14],
#     'max_features': [14],
#     'min_impurity_decrease': [14],
#     'n_estimators': [14]},
#    'vals': {'max_depth': [19.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [95.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 21, 803000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 23, 726000)},
#  {'state': 2,
#   'tid': 15,
#   'spec': None,
#   'result': {'loss': 28982.303852350462, 'status': 'ok'},
#   'misc': {'tid': 15,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [15],
#     'max_features': [15],
#     'min_impurity_decrease': [15],
#     'n_estimators': [15]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [82.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 23, 740000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 25, 563000)},
#  {'state': 2,
#   'tid': 16,
#   'spec': None,
#   'result': {'loss': 29524.89261802639, 'status': 'ok'},
#   'misc': {'tid': 16,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [16],
#     'max_features': [16],
#     'min_impurity_decrease': [16],
#     'n_estimators': [16]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [11.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 25, 572000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 27, 102000)},
#  {'state': 2,
#   'tid': 17,
#   'spec': None,
#   'result': {'loss': 29521.2711343184, 'status': 'ok'},
#   'misc': {'tid': 17,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [17],
#     'max_features': [17],
#     'min_impurity_decrease': [17],
#     'n_estimators': [17]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [10.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [99.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 27, 114000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 28, 866000)},
#  {'state': 2,
#   'tid': 18,
#   'spec': None,
#   'result': {'loss': 29693.493291063583, 'status': 'ok'},
#   'misc': {'tid': 18,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [18],
#     'max_features': [18],
#     'min_impurity_decrease': [18],
#     'n_estimators': [18]},
#    'vals': {'max_depth': [11.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [83.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 28, 875000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 30, 206000)},
#  {'state': 2,
#   'tid': 19,
#   'spec': None,
#   'result': {'loss': 29076.915038271232, 'status': 'ok'},
#   'misc': {'tid': 19,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [19],
#     'max_features': [19],
#     'min_impurity_decrease': [19],
#     'n_estimators': [19]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 30, 213000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 31, 852000)},
#  {'state': 2,
#   'tid': 20,
#   'spec': None,
#   'result': {'loss': 29383.687612900372, 'status': 'ok'},
#   'misc': {'tid': 20,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [20],
#     'max_features': [20],
#     'min_impurity_decrease': [20],
#     'n_estimators': [20]},
#    'vals': {'max_depth': [13.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [80.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 31, 896000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 33, 448000)},
#  {'state': 2,
#   'tid': 21,
#   'spec': None,
#   'result': {'loss': 28862.574759570947, 'status': 'ok'},
#   'misc': {'tid': 21,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [21],
#     'max_features': [21],
#     'min_impurity_decrease': [21],
#     'n_estimators': [21]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [81.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 33, 484000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 35, 406000)},
#  {'state': 2,
#   'tid': 22,
#   'spec': None,
#   'result': {'loss': 29262.350699053222, 'status': 'ok'},
#   'misc': {'tid': 22,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [22],
#     'max_features': [22],
#     'min_impurity_decrease': [22],
#     'n_estimators': [22]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [84.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 35, 458000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 37, 232000)},
#  {'state': 2,
#   'tid': 23,
#   'spec': None,
#   'result': {'loss': 29009.32124337125, 'status': 'ok'},
#   'misc': {'tid': 23,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [23],
#     'max_features': [23],
#     'min_impurity_decrease': [23],
#     'n_estimators': [23]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [96.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 37, 263000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 39, 77000)},
#  {'state': 2,
#   'tid': 24,
#   'spec': None,
#   'result': {'loss': 29122.80424757226, 'status': 'ok'},
#   'misc': {'tid': 24,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [24],
#     'max_features': [24],
#     'min_impurity_decrease': [24],
#     'n_estimators': [24]},
#    'vals': {'max_depth': [10.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [92.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 39, 115000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 40, 712000)},
#  {'state': 2,
#   'tid': 25,
#   'spec': None,
#   'result': {'loss': 29150.907805153798, 'status': 'ok'},
#   'misc': {'tid': 25,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [25],
#     'max_features': [25],
#     'min_impurity_decrease': [25],
#     'n_estimators': [25]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [86.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 40, 769000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 42, 417000)},
#  {'state': 2,
#   'tid': 26,
#   'spec': None,
#   'result': {'loss': 29133.316339694815, 'status': 'ok'},
#   'misc': {'tid': 26,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [26],
#     'max_features': [26],
#     'min_impurity_decrease': [26],
#     'n_estimators': [26]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [88.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 42, 455000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 44, 194000)},
#  {'state': 2,
#   'tid': 27,
#   'spec': None,
#   'result': {'loss': 28760.491695195706, 'status': 'ok'},
#   'misc': {'tid': 27,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [27],
#     'max_features': [27],
#     'min_impurity_decrease': [27],
#     'n_estimators': [27]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [91.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 44, 238000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 46, 227000)},
#  {'state': 2,
#   'tid': 28,
#   'spec': None,
#   'result': {'loss': 28874.788375693683, 'status': 'ok'},
#   'misc': {'tid': 28,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [28],
#     'max_features': [28],
#     'min_impurity_decrease': [28],
#     'n_estimators': [28]},
#    'vals': {'max_depth': [13.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [95.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 46, 268000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 48, 202000)},
#  {'state': 2,
#   'tid': 29,
#   'spec': None,
#   'result': {'loss': 28953.806788475154, 'status': 'ok'},
#   'misc': {'tid': 29,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [29],
#     'max_features': [29],
#     'min_impurity_decrease': [29],
#     'n_estimators': [29]},
#    'vals': {'max_depth': [12.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [80.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 48, 245000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 49, 895000)},
#  {'state': 2,
#   'tid': 30,
#   'spec': None,
#   'result': {'loss': 29137.749300493644, 'status': 'ok'},
#   'misc': {'tid': 30,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [30],
#     'max_features': [30],
#     'min_impurity_decrease': [30],
#     'n_estimators': [30]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [87.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 49, 944000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 51, 754000)},
#  {'state': 2,
#   'tid': 31,
#   'spec': None,
#   'result': {'loss': 29019.172671296285, 'status': 'ok'},
#   'misc': {'tid': 31,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [31],
#     'max_features': [31],
#     'min_impurity_decrease': [31],
#     'n_estimators': [31]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [93.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 51, 869000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 53, 681000)},
#  {'state': 2,
#   'tid': 32,
#   'spec': None,
#   'result': {'loss': 28910.090026695805, 'status': 'ok'},
#   'misc': {'tid': 32,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [32],
#     'max_features': [32],
#     'min_impurity_decrease': [32],
#     'n_estimators': [32]},
#    'vals': {'max_depth': [12.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [84.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 53, 724000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 55, 261000)},
#  {'state': 2,
#   'tid': 33,
#   'spec': None,
#   'result': {'loss': 29191.124356577006, 'status': 'ok'},
#   'misc': {'tid': 33,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [33],
#     'max_features': [33],
#     'min_impurity_decrease': [33],
#     'n_estimators': [33]},
#    'vals': {'max_depth': [19.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 55, 312000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 57, 135000)},
#  {'state': 2,
#   'tid': 34,
#   'spec': None,
#   'result': {'loss': 29384.726982569013, 'status': 'ok'},
#   'misc': {'tid': 34,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [34],
#     'max_features': [34],
#     'min_impurity_decrease': [34],
#     'n_estimators': [34]},
#    'vals': {'max_depth': [10.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [89.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 57, 177000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 0, 58, 524000)},
#  {'state': 2,
#   'tid': 35,
#   'spec': None,
#   'result': {'loss': 28971.481631893646, 'status': 'ok'},
#   'misc': {'tid': 35,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [35],
#     'max_features': [35],
#     'min_impurity_decrease': [35],
#     'n_estimators': [35]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [92.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 0, 58, 567000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 0, 595000)},
#  {'state': 2,
#   'tid': 36,
#   'spec': None,
#   'result': {'loss': 29405.18383119693, 'status': 'ok'},
#   'misc': {'tid': 36,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [36],
#     'max_features': [36],
#     'min_impurity_decrease': [36],
#     'n_estimators': [36]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [100.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 0, 643000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 2, 392000)},
#  {'state': 2,
#   'tid': 37,
#   'spec': None,
#   'result': {'loss': 29351.532847060007, 'status': 'ok'},
#   'misc': {'tid': 37,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [37],
#     'max_features': [37],
#     'min_impurity_decrease': [37],
#     'n_estimators': [37]},
#    'vals': {'max_depth': [13.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [89.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 2, 431000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 3, 929000)},
#  {'state': 2,
#   'tid': 38,
#   'spec': None,
#   'result': {'loss': 29693.48317365915, 'status': 'ok'},
#   'misc': {'tid': 38,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [38],
#     'max_features': [38],
#     'min_impurity_decrease': [38],
#     'n_estimators': [38]},
#    'vals': {'max_depth': [19.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [98.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 3, 998000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 5, 857000)},
#  {'state': 2,
#   'tid': 39,
#   'spec': None,
#   'result': {'loss': 29298.410865432787, 'status': 'ok'},
#   'misc': {'tid': 39,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [39],
#     'max_features': [39],
#     'min_impurity_decrease': [39],
#     'n_estimators': [39]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [91.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 5, 922000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 7, 671000)},
#  {'state': 2,
#   'tid': 40,
#   'spec': None,
#   'result': {'loss': 29245.15199846616, 'status': 'ok'},
#   'misc': {'tid': 40,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [40],
#     'max_features': [40],
#     'min_impurity_decrease': [40],
#     'n_estimators': [40]},
#    'vals': {'max_depth': [11.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [86.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 7, 720000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 9, 152000)},
#  {'state': 2,
#   'tid': 41,
#   'spec': None,
#   'result': {'loss': 28532.48096246216, 'status': 'ok'},
#   'misc': {'tid': 41,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [41],
#     'max_features': [41],
#     'min_impurity_decrease': [41],
#     'n_estimators': [41]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [96.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 9, 201000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 11, 58000)},
#  {'state': 2,
#   'tid': 42,
#   'spec': None,
#   'result': {'loss': 29219.983680610225, 'status': 'ok'},
#   'misc': {'tid': 42,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [42],
#     'max_features': [42],
#     'min_impurity_decrease': [42],
#     'n_estimators': [42]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 11, 107000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 12, 911000)},
#  {'state': 2,
#   'tid': 43,
#   'spec': None,
#   'result': {'loss': 29199.038056802478, 'status': 'ok'},
#   'misc': {'tid': 43,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [43],
#     'max_features': [43],
#     'min_impurity_decrease': [43],
#     'n_estimators': [43]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [96.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 12, 964000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 14, 936000)},
#  {'state': 2,
#   'tid': 44,
#   'spec': None,
#   'result': {'loss': 29054.004458201805, 'status': 'ok'},
#   'misc': {'tid': 44,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [44],
#     'max_features': [44],
#     'min_impurity_decrease': [44],
#     'n_estimators': [44]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [82.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 14, 992000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 16, 510000)},
#  {'state': 2,
#   'tid': 45,
#   'spec': None,
#   'result': {'loss': 29127.973176383523, 'status': 'ok'},
#   'misc': {'tid': 45,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [45],
#     'max_features': [45],
#     'min_impurity_decrease': [45],
#     'n_estimators': [45]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [93.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 16, 553000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 18, 516000)},
#  {'state': 2,
#   'tid': 46,
#   'spec': None,
#   'result': {'loss': 28865.232674158393, 'status': 'ok'},
#   'misc': {'tid': 46,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [46],
#     'max_features': [46],
#     'min_impurity_decrease': [46],
#     'n_estimators': [46]},
#    'vals': {'max_depth': [12.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [99.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 18, 552000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 20, 398000)},
#  {'state': 2,
#   'tid': 47,
#   'spec': None,
#   'result': {'loss': 29277.60213789896, 'status': 'ok'},
#   'misc': {'tid': 47,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [47],
#     'max_features': [47],
#     'min_impurity_decrease': [47],
#     'n_estimators': [47]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [88.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 20, 445000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 21, 955000)},
#  {'state': 2,
#   'tid': 48,
#   'spec': None,
#   'result': {'loss': 29710.56425469906, 'status': 'ok'},
#   'misc': {'tid': 48,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [48],
#     'max_features': [48],
#     'min_impurity_decrease': [48],
#     'n_estimators': [48]},
#    'vals': {'max_depth': [19.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [95.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 21, 992000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 23, 775000)},
#  {'state': 2,
#   'tid': 49,
#   'spec': None,
#   'result': {'loss': 29134.29028341081, 'status': 'ok'},
#   'misc': {'tid': 49,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [49],
#     'max_features': [49],
#     'min_impurity_decrease': [49],
#     'n_estimators': [49]},
#    'vals': {'max_depth': [11.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [91.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 23, 820000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 25, 379000)},
#  {'state': 2,
#   'tid': 50,
#   'spec': None,
#   'result': {'loss': 29645.235241938615, 'status': 'ok'},
#   'misc': {'tid': 50,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [50],
#     'max_features': [50],
#     'min_impurity_decrease': [50],
#     'n_estimators': [50]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [98.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 25, 429000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 27, 189000)},
#  {'state': 2,
#   'tid': 51,
#   'spec': None,
#   'result': {'loss': 28887.69511474843, 'status': 'ok'},
#   'misc': {'tid': 51,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [51],
#     'max_features': [51],
#     'min_impurity_decrease': [51],
#     'n_estimators': [51]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [96.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 27, 229000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 28, 983000)},
#  {'state': 2,
#   'tid': 52,
#   'spec': None,
#   'result': {'loss': 29078.601573138614, 'status': 'ok'},
#   'misc': {'tid': 52,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [52],
#     'max_features': [52],
#     'min_impurity_decrease': [52],
#     'n_estimators': [52]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [81.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 29, 26000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 30, 640000)},
#  {'state': 2,
#   'tid': 53,
#   'spec': None,
#   'result': {'loss': 29437.474673989745, 'status': 'ok'},
#   'misc': {'tid': 53,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [53],
#     'max_features': [53],
#     'min_impurity_decrease': [53],
#     'n_estimators': [53]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [11.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [84.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 30, 712000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 31, 925000)},
#  {'state': 2,
#   'tid': 54,
#   'spec': None,
#   'result': {'loss': 29307.284348559413, 'status': 'ok'},
#   'misc': {'tid': 54,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [54],
#     'max_features': [54],
#     'min_impurity_decrease': [54],
#     'n_estimators': [54]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [85.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 31, 993000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 33, 415000)},
#  {'state': 2,
#   'tid': 55,
#   'spec': None,
#   'result': {'loss': 28944.704780791733, 'status': 'ok'},
#   'misc': {'tid': 55,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [55],
#     'max_features': [55],
#     'min_impurity_decrease': [55],
#     'n_estimators': [55]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [90.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 33, 490000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 35, 217000)},
#  {'state': 2,
#   'tid': 56,
#   'spec': None,
#   'result': {'loss': 29246.179324742967, 'status': 'ok'},
#   'misc': {'tid': 56,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [56],
#     'max_features': [56],
#     'min_impurity_decrease': [56],
#     'n_estimators': [56]},
#    'vals': {'max_depth': [13.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [100.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 35, 306000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 37, 220000)},
#  {'state': 2,
#   'tid': 57,
#   'spec': None,
#   'result': {'loss': 29085.66006193342, 'status': 'ok'},
#   'misc': {'tid': 57,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [57],
#     'max_features': [57],
#     'min_impurity_decrease': [57],
#     'n_estimators': [57]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [98.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 37, 327000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 39, 122000)},
#  {'state': 2,
#   'tid': 58,
#   'spec': None,
#   'result': {'loss': 29108.870257890852, 'status': 'ok'},
#   'misc': {'tid': 58,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [58],
#     'max_features': [58],
#     'min_impurity_decrease': [58],
#     'n_estimators': [58]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [99.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 39, 206000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 41, 36000)},
#  {'state': 2,
#   'tid': 59,
#   'spec': None,
#   'result': {'loss': 29296.343196926035, 'status': 'ok'},
#   'misc': {'tid': 59,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [59],
#     'max_features': [59],
#     'min_impurity_decrease': [59],
#     'n_estimators': [59]},
#    'vals': {'max_depth': [25.0],
#     'max_features': [10.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [92.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 41, 113000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 42, 525000)},
#  {'state': 2,
#   'tid': 60,
#   'spec': None,
#   'result': {'loss': 29020.938112700107, 'status': 'ok'},
#   'misc': {'tid': 60,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [60],
#     'max_features': [60],
#     'min_impurity_decrease': [60],
#     'n_estimators': [60]},
#    'vals': {'max_depth': [12.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 42, 587000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 43, 974000)},
#  {'state': 2,
#   'tid': 61,
#   'spec': None,
#   'result': {'loss': 28929.180289820262, 'status': 'ok'},
#   'misc': {'tid': 61,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [61],
#     'max_features': [61],
#     'min_impurity_decrease': [61],
#     'n_estimators': [61]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [88.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 44, 29000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 45, 408000)},
#  {'state': 2,
#   'tid': 62,
#   'spec': None,
#   'result': {'loss': 29258.53198034806, 'status': 'ok'},
#   'misc': {'tid': 62,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [62],
#     'max_features': [62],
#     'min_impurity_decrease': [62],
#     'n_estimators': [62]},
#    'vals': {'max_depth': [10.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [93.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 45, 457000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 46, 445000)},
#  {'state': 2,
#   'tid': 63,
#   'spec': None,
#   'result': {'loss': 28779.1140678209, 'status': 'ok'},
#   'misc': {'tid': 63,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [63],
#     'max_features': [63],
#     'min_impurity_decrease': [63],
#     'n_estimators': [63]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [81.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 46, 478000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 47, 551000)},
#  {'state': 2,
#   'tid': 64,
#   'spec': None,
#   'result': {'loss': 28919.380635658745, 'status': 'ok'},
#   'misc': {'tid': 64,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [64],
#     'max_features': [64],
#     'min_impurity_decrease': [64],
#     'n_estimators': [64]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [83.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 47, 596000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 48, 984000)},
#  {'state': 2,
#   'tid': 65,
#   'spec': None,
#   'result': {'loss': 29219.498035948047, 'status': 'ok'},
#   'misc': {'tid': 65,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [65],
#     'max_features': [65],
#     'min_impurity_decrease': [65],
#     'n_estimators': [65]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 49, 23000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 50, 643000)},
#  {'state': 2,
#   'tid': 66,
#   'spec': None,
#   'result': {'loss': 28874.788375693675, 'status': 'ok'},
#   'misc': {'tid': 66,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [66],
#     'max_features': [66],
#     'min_impurity_decrease': [66],
#     'n_estimators': [66]},
#    'vals': {'max_depth': [13.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [95.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 50, 697000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 52, 149000)},
#  {'state': 2,
#   'tid': 67,
#   'spec': None,
#   'result': {'loss': 28812.622907752888, 'status': 'ok'},
#   'misc': {'tid': 67,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [67],
#     'max_features': [67],
#     'min_impurity_decrease': [67],
#     'n_estimators': [67]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 52, 195000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 53, 699000)},
#  {'state': 2,
#   'tid': 68,
#   'spec': None,
#   'result': {'loss': 28976.30290941116, 'status': 'ok'},
#   'misc': {'tid': 68,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [68],
#     'max_features': [68],
#     'min_impurity_decrease': [68],
#     'n_estimators': [68]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [96.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 53, 747000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 55, 351000)},
#  {'state': 2,
#   'tid': 69,
#   'spec': None,
#   'result': {'loss': 28872.75125963249, 'status': 'ok'},
#   'misc': {'tid': 69,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [69],
#     'max_features': [69],
#     'min_impurity_decrease': [69],
#     'n_estimators': [69]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [100.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 55, 398000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 57, 115000)},
#  {'state': 2,
#   'tid': 70,
#   'spec': None,
#   'result': {'loss': 29208.648273375147, 'status': 'ok'},
#   'misc': {'tid': 70,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [70],
#     'max_features': [70],
#     'min_impurity_decrease': [70],
#     'n_estimators': [70]},
#    'vals': {'max_depth': [13.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [99.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 57, 174000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 1, 58, 789000)},
#  {'state': 2,
#   'tid': 71,
#   'spec': None,
#   'result': {'loss': 29016.007293336348, 'status': 'ok'},
#   'misc': {'tid': 71,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [71],
#     'max_features': [71],
#     'min_impurity_decrease': [71],
#     'n_estimators': [71]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [95.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 1, 58, 843000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 2, 0, 473000)},
#  {'state': 2,
#   'tid': 72,
#   'spec': None,
#   'result': {'loss': 29086.48283969523, 'status': 'ok'},
#   'misc': {'tid': 72,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [72],
#     'max_features': [72],
#     'min_impurity_decrease': [72],
#     'n_estimators': [72]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 2, 0, 514000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 2, 3, 365000)},
#  {'state': 2,
#   'tid': 73,
#   'spec': None,
#   'result': {'loss': 28888.317436429246, 'status': 'ok'},
#   'misc': {'tid': 73,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [73],
#     'max_features': [73],
#     'min_impurity_decrease': [73],
#     'n_estimators': [73]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [89.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 2, 3, 425000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 2, 5, 438000)},
#  {'state': 2,
#   'tid': 74,
#   'spec': None,
#   'result': {'loss': 28934.87022799626, 'status': 'ok'},
#   'misc': {'tid': 74,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [74],
#     'max_features': [74],
#     'min_impurity_decrease': [74],
#     'n_estimators': [74]},
#    'vals': {'max_depth': [12.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [86.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 2, 5, 489000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 2, 6, 655000)},
#  {'state': 2,
#   'tid': 75,
#   'spec': None,
#   'result': {'loss': 29490.510186976677, 'status': 'ok'},
#   'misc': {'tid': 75,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [75],
#     'max_features': [75],
#     'min_impurity_decrease': [75],
#     'n_estimators': [75]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 2, 6, 693000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 2, 7, 892000)},
#  {'state': 2,
#   'tid': 76,
#   'spec': None,
#   'result': {'loss': 29528.184751211025, 'status': 'ok'},
#   'misc': {'tid': 76,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [76],
#     'max_features': [76],
#     'min_impurity_decrease': [76],
# ...
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 3, 49, 341000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 3, 50, 741000)},
#  {'state': 2,
#   'tid': 154,
#   'spec': None,
#   'result': {'loss': 29100.90030768008, 'status': 'ok'},
#   'misc': {'tid': 154,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [154],
#     'max_features': [154],
#     'min_impurity_decrease': [154],
#     'n_estimators': [154]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 3, 50, 798000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 3, 52, 23000)},
#  {'state': 2,
#   'tid': 155,
#   'spec': None,
#   'result': {'loss': 29074.785198925536, 'status': 'ok'},
#   'misc': {'tid': 155,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [155],
#     'max_features': [155],
#     'min_impurity_decrease': [155],
#     'n_estimators': [155]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 3, 52, 86000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 3, 53, 396000)},
#  {'state': 2,
#   'tid': 156,
#   'spec': None,
#   'result': {'loss': 28895.763523622136, 'status': 'ok'},
#   'misc': {'tid': 156,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [156],
#     'max_features': [156],
#     'min_impurity_decrease': [156],
#     'n_estimators': [156]},
#    'vals': {'max_depth': [13.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [100.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 3, 53, 459000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 3, 54, 760000)},
#  {'state': 2,
#   'tid': 157,
#   'spec': None,
#   'result': {'loss': 28808.41989667205, 'status': 'ok'},
#   'misc': {'tid': 157,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [157],
#     'max_features': [157],
#     'min_impurity_decrease': [157],
#     'n_estimators': [157]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [93.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 3, 54, 819000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 3, 56)},
#  {'state': 2,
#   'tid': 158,
#   'spec': None,
#   'result': {'loss': 29245.48305294551, 'status': 'ok'},
#   'misc': {'tid': 158,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [158],
#     'max_features': [158],
#     'min_impurity_decrease': [158],
#     'n_estimators': [158]},
#    'vals': {'max_depth': [12.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [95.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 3, 56, 63000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 3, 57, 232000)},
#  {'state': 2,
#   'tid': 159,
#   'spec': None,
#   'result': {'loss': 28861.867800013035, 'status': 'ok'},
#   'misc': {'tid': 159,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [159],
#     'max_features': [159],
#     'min_impurity_decrease': [159],
#     'n_estimators': [159]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [96.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 3, 57, 300000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 3, 58, 688000)},
#  {'state': 2,
#   'tid': 160,
#   'spec': None,
#   'result': {'loss': 28917.453223147, 'status': 'ok'},
#   'misc': {'tid': 160,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [160],
#     'max_features': [160],
#     'min_impurity_decrease': [160],
#     'n_estimators': [160]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [99.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 3, 58, 749000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 0, 131000)},
#  {'state': 2,
#   'tid': 161,
#   'spec': None,
#   'result': {'loss': 28901.02564623068, 'status': 'ok'},
#   'misc': {'tid': 161,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [161],
#     'max_features': [161],
#     'min_impurity_decrease': [161],
#     'n_estimators': [161]},
#    'vals': {'max_depth': [13.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 0, 193000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 1, 465000)},
#  {'state': 2,
#   'tid': 162,
#   'spec': None,
#   'result': {'loss': 28843.77336586942, 'status': 'ok'},
#   'misc': {'tid': 162,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [162],
#     'max_features': [162],
#     'min_impurity_decrease': [162],
#     'n_estimators': [162]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [93.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 1, 525000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 2, 849000)},
#  {'state': 2,
#   'tid': 163,
#   'spec': None,
#   'result': {'loss': 29087.774143809238, 'status': 'ok'},
#   'misc': {'tid': 163,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [163],
#     'max_features': [163],
#     'min_impurity_decrease': [163],
#     'n_estimators': [163]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [98.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 2, 912000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 4, 360000)},
#  {'state': 2,
#   'tid': 164,
#   'spec': None,
#   'result': {'loss': 28531.223012433667, 'status': 'ok'},
#   'misc': {'tid': 164,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [164],
#     'max_features': [164],
#     'min_impurity_decrease': [164],
#     'n_estimators': [164]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 4, 429000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 5, 765000)},
#  {'state': 2,
#   'tid': 165,
#   'spec': None,
#   'result': {'loss': 28990.537154588994, 'status': 'ok'},
#   'misc': {'tid': 165,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [165],
#     'max_features': [165],
#     'min_impurity_decrease': [165],
#     'n_estimators': [165]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [92.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 5, 844000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 7, 204000)},
#  {'state': 2,
#   'tid': 166,
#   'spec': None,
#   'result': {'loss': 29608.757816390054, 'status': 'ok'},
#   'misc': {'tid': 166,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [166],
#     'max_features': [166],
#     'min_impurity_decrease': [166],
#     'n_estimators': [166]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 7, 278000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 8, 487000)},
#  {'state': 2,
#   'tid': 167,
#   'spec': None,
#   'result': {'loss': 29234.655376790684, 'status': 'ok'},
#   'misc': {'tid': 167,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [167],
#     'max_features': [167],
#     'min_impurity_decrease': [167],
#     'n_estimators': [167]},
#    'vals': {'max_depth': [13.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [91.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 8, 566000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 9, 798000)},
#  {'state': 2,
#   'tid': 168,
#   'spec': None,
#   'result': {'loss': 29383.521973117127, 'status': 'ok'},
#   'misc': {'tid': 168,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [168],
#     'max_features': [168],
#     'min_impurity_decrease': [168],
#     'n_estimators': [168]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [95.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 9, 859000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 11, 169000)},
#  {'state': 2,
#   'tid': 169,
#   'spec': None,
#   'result': {'loss': 29152.920107930502, 'status': 'ok'},
#   'misc': {'tid': 169,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [169],
#     'max_features': [169],
#     'min_impurity_decrease': [169],
#     'n_estimators': [169]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 11, 232000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 12, 489000)},
#  {'state': 2,
#   'tid': 170,
#   'spec': None,
#   'result': {'loss': 29330.388586611247, 'status': 'ok'},
#   'misc': {'tid': 170,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [170],
#     'max_features': [170],
#     'min_impurity_decrease': [170],
#     'n_estimators': [170]},
#    'vals': {'max_depth': [12.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [92.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 12, 560000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 13, 558000)},
#  {'state': 2,
#   'tid': 171,
#   'spec': None,
#   'result': {'loss': 28807.163805138745, 'status': 'ok'},
#   'misc': {'tid': 171,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [171],
#     'max_features': [171],
#     'min_impurity_decrease': [171],
#     'n_estimators': [171]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [91.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 13, 623000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 14, 927000)},
#  {'state': 2,
#   'tid': 172,
#   'spec': None,
#   'result': {'loss': 29107.037564496044, 'status': 'ok'},
#   'misc': {'tid': 172,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [172],
#     'max_features': [172],
#     'min_impurity_decrease': [172],
#     'n_estimators': [172]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [96.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 14, 992000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 16, 272000)},
#  {'state': 2,
#   'tid': 173,
#   'spec': None,
#   'result': {'loss': 28546.260780099972, 'status': 'ok'},
#   'misc': {'tid': 173,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [173],
#     'max_features': [173],
#     'min_impurity_decrease': [173],
#     'n_estimators': [173]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [93.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 16, 349000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 17, 600000)},
#  {'state': 2,
#   'tid': 174,
#   'spec': None,
#   'result': {'loss': 29018.0077641247, 'status': 'ok'},
#   'misc': {'tid': 174,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [174],
#     'max_features': [174],
#     'min_impurity_decrease': [174],
#     'n_estimators': [174]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 17, 675000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 19, 75000)},
#  {'state': 2,
#   'tid': 175,
#   'spec': None,
#   'result': {'loss': 29252.67880882512, 'status': 'ok'},
#   'misc': {'tid': 175,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [175],
#     'max_features': [175],
#     'min_impurity_decrease': [175],
#     'n_estimators': [175]},
#    'vals': {'max_depth': [12.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [100.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 19, 153000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 20, 397000)},
#  {'state': 2,
#   'tid': 176,
#   'spec': None,
#   'result': {'loss': 28802.523405561533, 'status': 'ok'},
#   'misc': {'tid': 176,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [176],
#     'max_features': [176],
#     'min_impurity_decrease': [176],
#     'n_estimators': [176]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [86.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 20, 466000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 21, 507000)},
#  {'state': 2,
#   'tid': 177,
#   'spec': None,
#   'result': {'loss': 28841.086179852187, 'status': 'ok'},
#   'misc': {'tid': 177,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [177],
#     'max_features': [177],
#     'min_impurity_decrease': [177],
#     'n_estimators': [177]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [95.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 21, 576000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 22, 893000)},
#  {'state': 2,
#   'tid': 178,
#   'spec': None,
#   'result': {'loss': 28850.54830565668, 'status': 'ok'},
#   'misc': {'tid': 178,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [178],
#     'max_features': [178],
#     'min_impurity_decrease': [178],
#     'n_estimators': [178]},
#    'vals': {'max_depth': [19.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [90.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 12, 12, 4, 23, 60000),
#   'refresh_time': datetime.datetime(2022, 5, 12, 12, 4, 24, 272000)}]
